# %% [markdown]
# # Check Python Libraries

# %%
import numpy
numpy.__version__
# Out:
# '1.9.2'

# %%
import sklearn
sklearn.__version__
# Out:
# '0.16.1'

# %%
import scipy
scipy.__version__
# Out:
# '0.15.1'

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
scatter(rand(50), rand(50), s=rand(50)*500, c=rand(50), alpha=0.8)
